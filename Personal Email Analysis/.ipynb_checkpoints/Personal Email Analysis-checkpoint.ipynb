# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import mailbox

# %%
mailboxfile = "C:/Users/HP/takeout-20220527T154953Z-001/Takeout/Mail/All mail Including Spam and Trash.mbox"

mbox = mailbox.mbox(mailboxfile)
mbox

# %%
for key in mbox[0].keys():
    print(key)
# Out:
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# X-Google-DKIM-Signature
# X-Gm-Message-State
# X-Google-Smtp-Source
# MIME-Version
# X-Received
# Date
# List-Unsubscribe
# X-Notifications
# X-Notifications-Bounce-Info
# Message-ID
# Subject
# From
# To
# Content-Type

# %%
import csv

# %%
with open('mailbox.csv', 'w') as outputfile:
    writer = csv.writer(outputfile)
    writer.writerow(['subject','from','date','to','label','thread'])
    for message in mbox:
        writer.writerow([
            message['subject'],
            message['from'],
            message['date'],
            message['to'],
            message['X-Gmail-Labels'],
            message['X-GM-THRID']
        ])

# %%
dfs = pd.read_csv('mailbox.csv', names=['subject', 'from', 'date', 'to',
'label', 'thread'])

# %%
dfs
# Out:
#                                                  subject  \
# 0                                                subject
# 1      =?UTF-8?Q?3_new_jobs_for_=E2=80=98data_scienti...
# 2              Your program recommendations for the week
# 3      =?utf-8?Q?Excel=20Newsletter=20=2D=20STOP=20Em...
# 4      =?UTF-8?Q?*Konga_Food_is_now_live_in_Lagos!*_=...
# ...                                                  ...
# 21562     Declined Card Transaction - Insufficient Funds
# 21563         Ready to Make Your Career Goals a Reality?
# 21564                     =?utf-8?q?Are_PhDs_a_scam=3F?=
# 21565  =?UTF-8?Q?Instablog9ja_Tweeted:_Shock_as_swar?...
# 21566  Node Congress Tweeted: This workshop will help...
#
#                                                     from  \
# 0                                                   from
# 1      Job alerts from Google <notify-noreply@google....
# 2                       "Will at edX" <edX@news.edx.org>
# 3      =?utf-8?Q?My=20Online=20Training=20Hub?= <webs...
# 4                 Konga Food <Newsletter@info.konga.com>
# ...                                                  ...
# 21562             "GeNS@gtbank.com" <noreply@gtbank.com>
# 21563                 "Kaplan" <kaplan@mail.kaptest.com>
# 21564    Quora Digest <english-digest-noreply@quora.com>
# 21565                         Twitter <info@twitter.com>
# 21566                         Twitter <info@twitter.com>
#
#                                   date  \
# 0                                 date
# 1      Tue, 24 May 2022 12:27:26 -0700
# 2      Thu, 26 May 2022 14:00:10 +0000
# 3      Thu, 26 May 2022 12:06:07 +0000
# 4      Mon, 23 May 2022 15:25:50 +0530
# ...                                ...
# 21562  Sun, 18 Jul 2021 08:16:30 +0100
# 21563       16 Dec 2021 07:27:57 -0800
# 21564  Wed, 18 Aug 2021 17:29:08 +0000
# 21565  Fri, 01 Apr 2022 14:38:18 +0000
# 21566  Fri, 18 Mar 2022 09:48:57 +0000
#
#                                              to  \
# 0                                            to
# 1                       ayosamobitade@gmail.com
# 2                       ayosamobitade@gmail.com
# 3                     <Ayosamobitade@gmail.com>
# 4                       ayosamobitade@gmail.com
# ...                                         ...
# 21562                 <ayosamobitade@gmail.com>
# 21563                   ayosamobitade@gmail.com
# 21564                   ayosamobitade@gmail.com
# 21565  Samworld Press <ayosamobitade@gmail.com>
# 21566  Samworld Press <ayosamobitade@gmail.com>
#
#                                   label               thread
# 0                                 label               thread
# 1         Inbox,Opened,Category Updates  1733736999130792636
# 2      Inbox,Category Promotions,Unread  1733897612589550289
# 3         Inbox,Category Updates,Unread  1733890522517290196
# 4      Inbox,Category Promotions,Unread  1733610439749409235
# ...                                 ...                  ...
# 21562     Inbox,Category Updates,Unread  1705605969799682813
# 21563  Inbox,Category Promotions,Unread  1719317334410978885
# 21564     Inbox,Category Updates,Unread  1708453002325720055
# 21565      Inbox,Category Social,Unread  1728917168752283375
# 21566      Inbox,Category Social,Unread  1727630607146151356
#
# [21567 rows x 6 columns]

# %%
dfs.dtypes
# Out:
# subject    object
# from       object
# date       object
# to         object
# label      object
# thread     object
# dtype: object

# %%
dfs['date'] = dfs['date'].apply(lambda x: pd.to_datetime(x, errors='coerce', utc=True))
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\dateutil\parser\_parser.py:1218: UnknownTimezoneWarning: tzname CDT identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\HP\anaconda3\lib\site-packages\dateutil\parser\_parser.py:1218: UnknownTimezoneWarning: tzname CST identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
# C:\Users\HP\anaconda3\lib\site-packages\dateutil\parser\_parser.py:1218: UnknownTimezoneWarning: tzname EST identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)

# %%
dfs.dtypes
# Out:
# subject                 object
# from                    object
# date       datetime64[ns, UTC]
# to                      object
# label                   object
# thread                  object
# dtype: object

# %%
## Removing the Nan values

# %%
dfs = dfs[dfs['date'].notna()]

# %%
## Applying descriptive statistics

# %%
dfs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21565 entries, 1 to 21566
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   subject  21502 non-null  object
#  1   from     21565 non-null  object
#  2   date     21565 non-null  datetime64[ns, UTC]
#  3   to       21545 non-null  object
#  4   label    21565 non-null  object
#  5   thread   21565 non-null  object
# dtypes: datetime64[ns, UTC](1), object(5)
# memory usage: 1.2+ MB

# %%
# Note that ther are 21565 emails

# %%
dfs.head(10)
# Out:
#                                               subject  \
# 1   =?UTF-8?Q?3_new_jobs_for_=E2=80=98data_scienti...
# 2           Your program recommendations for the week
# 3   =?utf-8?Q?Excel=20Newsletter=20=2D=20STOP=20Em...
# 4   =?UTF-8?Q?*Konga_Food_is_now_live_in_Lagos!*_=...
# 5                   30+ new jobs for 'data scientist'
# 6   Re: [DataTalksClub/data-engineering-zoomcamp] ...
# 7   Re: [DataTalksClub/data-engineering-zoomcamp] ...
# 8   [DataTalksClub/data-engineering-zoomcamp] Time...
# 9   =?utf-8?q?I_was_refused_a_USA_visa_on_a_counte...
# 10                 GRE Question of the Day for May 15
#
#                                                  from  \
# 1   Job alerts from Google <notify-noreply@google....
# 2                    "Will at edX" <edX@news.edx.org>
# 3   =?utf-8?Q?My=20Online=20Training=20Hub?= <webs...
# 4              Konga Food <Newsletter@info.konga.com>
# 5   LinkedIn Job Alerts <jobalerts-noreply@linkedi...
# 6          Alexey Grigorev <notifications@github.com>
# 7          Alexey Grigorev <notifications@github.com>
# 8          Alexey Grigorev <notifications@github.com>
# 9   Quora Digest <english-personalized-digest@quor...
# 10  "Kaplan Test Prep" <kaplantestprep@mail.kaptes...
#
#                         date  \
# 1  2022-05-24 19:27:26+00:00
# 2  2022-05-26 14:00:10+00:00
# 3  2022-05-26 12:06:07+00:00
# 4  2022-05-23 09:55:50+00:00
# 5  2022-05-23 15:04:34+00:00
# 6  2022-05-22 20:53:24+00:00
# 7  2022-05-22 20:53:22+00:00
# 8  2022-05-20 05:59:07+00:00
# 9  2022-05-22 04:12:22+00:00
# 10 2022-05-15 13:35:13+00:00
#
#                                                    to  \
# 1                             ayosamobitade@gmail.com
# 2                             ayosamobitade@gmail.com
# 3                           <Ayosamobitade@gmail.com>
# 4                             ayosamobitade@gmail.com
# 5   "Ayobami Samuel Obitade B.Tech" <ayosamobitade...
# 6   DataTalksClub/data-engineering-zoomcamp <data-...
# 7   DataTalksClub/data-engineering-zoomcamp <data-...
# 8   DataTalksClub/data-engineering-zoomcamp <data-...
# 9                             ayosamobitade@gmail.com
# 10                          <ayosamobitade@gmail.com>
#
#                                label               thread
# 1      Inbox,Opened,Category Updates  1733736999130792636
# 2   Inbox,Category Promotions,Unread  1733897612589550289
# 3      Inbox,Category Updates,Unread  1733890522517290196
# 4   Inbox,Category Promotions,Unread  1733610439749409235
# 5      Inbox,Category Updates,Unread  1733629866042045910
# 6       Trash,Opened,Category Forums  1733323756223473963
# 7       Trash,Opened,Category Forums  1733323756223473963
# 8      Trash,Opened,Category Updates  1733323756223473963
# 9      Inbox,Category Updates,Unread  1733498234232534466
# 10  Inbox,Category Promotions,Unread  1732899544725135310

# %%
## Data refactoring

# %%
# creating an email extractor

import re

def extract_email_address(string):
    email = re.findall(r'<(.+?)>', string)
    if not email:
        email = list(filter(lambda y: '@' in y, string.split()))
        return email[0] if email else np.nan

# %%
# applying the email extractor

dfs['from'] = dfs['from'].apply(lambda x: extract_email_address(x))
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
dfs.sample(10)
# Out:
#                                                  subject  from  \
# 563       Declined Card Transaction - Insufficient Funds  None
# 14914            GRE Question of the Day for September 8  None
# 18789  5 Things You Didn't Know About The Japanese La...  None
# 14112               GRE Question of the Day for March 23  None
# 7966   =?utf-8?q?If_I_come_to_the_US_with_a_visiting_...  None
# 18178                              Jobs for the Weekend!  None
# 3848             GeNS Transaction Alert [Debit: 500.00 ]  None
# 16017  Free Courses + New Skills Waiting For You, Ayo...  None
# 16095               1 new digital marketer job in Ibadan  None
# 526             =?utf-8?Q?1 advertising jobs in lagos?=   None
#
#                            date  \
# 563   2022-04-26 20:19:20+00:00
# 14914 2019-09-08 14:03:07+00:00
# 18789 2018-05-19 14:26:50+00:00
# 14112 2020-03-23 12:04:20+00:00
# 7966  2021-02-15 13:20:45+00:00
# 18178 2019-06-07 15:31:06+00:00
# 3848  2021-08-21 15:41:20+00:00
# 16017 2019-07-17 04:59:14+00:00
# 16095 2019-05-04 13:15:15+00:00
# 526   2022-03-08 14:26:05+00:00
#
#                                                      to  \
# 563                           <ayosamobitade@gmail.com>
# 14914                         <ayosamobitade@gmail.com>
# 18789  Ayobami Samuel Obitade <ayosamobitade@gmail.com>
# 14112                         <ayosamobitade@gmail.com>
# 7966                            ayosamobitade@gmail.com
# 18178                 Ayobami <ayosamobitade@gmail.com>
# 3848                          <ayosamobitade@gmail.com>
# 16017  Ayobami Samuel Obitade <ayosamobitade@gmail.com>
# 16095                           ayosamobitade@gmail.com
# 526                             ayosamobitade@gmail.com
#
#                                   label               thread
# 563      Inbox,Category Personal,Unread  1731198051184393017
# 14914  Inbox,Category Promotions,Unread  1644116224237682296
# 18789  Inbox,Category Promotions,Unread  1600902959515520407
# 14112  Inbox,Category Promotions,Unread  1661956490503036161
# 7966      Inbox,Category Updates,Unread  1691767534623350214
# 18178     Inbox,Category Updates,Unread  1635694853657493130
# 3848      Inbox,Category Updates,Unread  1708718015532199668
# 16017  Inbox,Category Promotions,Unread  1639280338933298245
# 16095     Inbox,Category Updates,Unread  1632607368012725720
# 526       Inbox,Category Updates,Unread  1726742073355769078

# %%
myemail = 'ayosamobitade@gmail.com'
dfs['label'] = dfs['from'].apply(lambda x: 'sent' if x==myemail else 'inbox')
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
